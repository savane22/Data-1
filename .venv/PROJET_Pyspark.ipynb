# %% [markdown]
# 🕵️‍♂️ Analyse des crimes à Chicago (2001 - Présent)
#
#
# 🎯 Objectif du projet
#
# Ce projet a pour but d’explorer et d’analyser les données publiques sur les crimes enregistrés à Chicago depuis 2001, à l’aide de PySpark, un outil puissant pour le traitement de données volumineuses.
# L’objectif est de comprendre les tendances criminelles et d’identifier les types d’infractions les plus fréquents.

# %%
#! pip install pyspark -q
#! pip install findspark -p

# %%
from pyspark.sql import SparkSession

# Création ou récupération d'une session Spark
spark = SparkSession.builder \
    .appName("Analyse des crimes à Chicago") \
    .getOrCreate()

# Lecture du fichier CSV
df = spark.read.csv("C:/Users/savan/Downloads/Crimes_-_2001_to_Present_20251021.csv", header=True, inferSchema=True)

# Afficher les 20 premières lignes
df.show(n = 20, truncate = False)
# Out:
# +--------+-----------+----------------------+-----------------------+----+--------------------------+--------------------------------------------------+-------------------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+----------------------+------------+-------------+-----------------------------+
# |ID      |Case Number|Date                  |Block                  |IUCR|Primary Type              |Description                                       |Location Description           |Arrest|Domestic|Beat|District|Ward|Community Area|FBI Code|X Coordinate|Y Coordinate|Year|Updated On            |Latitude    |Longitude    |Location                     |
# +--------+-----------+----------------------+-----------------------+----+--------------------------+--------------------------------------------------+-------------------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+----------------------+------------+-------------+-----------------------------+
# |13997897|JJ450669   |10/13/2025 12:00:00 AM|090XX S BURLEY AVE     |1710|OFFENSE INVOLVING CHILDREN|ENDANGERING LIFE / HEALTH OF CHILD                |APARTMENT                      |false |false   |424 |4       |10  |46            |20      |1199242     |1845609     |2025|10/20/2025 03:43:24 PM|41.731158264|-87.545686555|(41.731158264, -87.545686555)|
# |14001487|JJ456213   |10/13/2025 12:00:00 AM|135XX S BRANDON AVE    |0910|MOTOR VEHICLE THEFT       |AUTOMOBILE                                        |RESIDENCE                      |false |false   |433 |4       |10  |55            |07      |NULL        |NULL        |2025|10/20/2025 03:43:24 PM|NULL        |NULL         |NULL                         |
# |13996431|JJ450180   |10/13/2025 12:00:00 AM|018XX N LINDER AVE     |0710|THEFT                     |THEFT FROM MOTOR VEHICLE                          |STREET                         |false |false   |2532|25      |37  |25            |06      |1139442     |1911645     |2025|10/20/2025 03:43:24 PM|41.913664297|-87.76315256 |(41.913664297, -87.76315256) |
# |13996029|JJ449576   |10/13/2025 12:00:00 AM|057XX W OHIO ST        |0460|BATTERY                   |SIMPLE                                            |STREET                         |false |false   |1512|15      |29  |25            |08B     |1137927     |1903397     |2025|10/20/2025 03:43:24 PM|41.891058284|-87.768917826|(41.891058284, -87.768917826)|
# |13996983|JJ450693   |10/13/2025 12:00:00 AM|081XX S ELLIS AVE      |0810|THEFT                     |OVER $500                                         |APARTMENT                      |false |false   |631 |6       |8   |44            |06      |1184307     |1851311     |2025|10/20/2025 03:43:24 PM|41.747167184|-87.600220148|(41.747167184, -87.600220148)|
# |13995996|JJ449583   |10/13/2025 12:00:00 AM|010XX W BRYN MAWR AVE  |0486|BATTERY                   |DOMESTIC BATTERY SIMPLE                           |APARTMENT                      |false |true    |2022|20      |48  |77            |08B     |1168062     |1937365     |2025|10/20/2025 03:43:24 PM|41.983670812|-87.657262868|(41.983670812, -87.657262868)|
# |13996002|JJ449532   |10/12/2025 11:52:00 PM|039XX N LINCOLN AVE    |
# |13995985|JJ449533   |10/12/2025 11:51:00 PM|0000X W HUBBARD ST     |
# |13996008|JJ449538   |10/12/2025 11:50:00 PM|081XX S ELLIS AVE      |
# +--------+-----------+----------------------+-----------------------+
# only showing top 20 rows

# %%
# Le nombre de ligne
df.count()
# Out:
# 8425337

# %%
# Le type de mon données
type(df)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
# Le type des variables
df.printSchema()
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- Case Number: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Block: string (nullable = true)
#  |-- IUCR: string (nullable = true)
#  |-- Primary Type: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Location Description: string (nullable = true)
#  |-- Arrest: boolean (nullable = true)
#  |-- Domestic: boolean (nullable = true)
#  |-- Beat: integer (nullable = true)
#  |-- District: integer (nullable = true)
#  |-- Ward: integer (nullable = true)
#  |-- Community Area: integer (nullable = true)
#  |-- FBI Code: string (nullable = true)
#  |-- X Coordinate: integer (nullable = true)
#  |-- Y Coordinate: integer (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Updated On: string (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Location: string (nullable = true)

# %% [markdown]
# Manipulation des données

# %%
# Convertir la colonne Date en format Date
df = df.withColumn(
   "Date",
   to_timestamp(col("Date"), "MM/dd/yyyy hh:mm:ss a")
)

df.printSchema()
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- Case Number: string (nullable = true)
#  |-- Date: timestamp (nullable = true)
#  |-- Block: string (nullable = true)
#  |-- IUCR: string (nullable = true)
#  |-- Primary Type: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Location Description: string (nullable = true)
#  |-- Arrest: boolean (nullable = true)
#  |-- Domestic: boolean (nullable = true)
#  |-- Beat: integer (nullable = true)
#  |-- District: integer (nullable = true)
#  |-- Ward: integer (nullable = true)
#  |-- Community Area: integer (nullable = true)
#  |-- FBI Code: string (nullable = true)
#  |-- X Coordinate: integer (nullable = true)
#  |-- Y Coordinate: integer (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Updated On: string (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Location: string (nullable = true)

# %%
# Afficher les 5 premières lignes
df.show(5)
# Out:
# +--------+-----------+-------------------+-------------------+----+--------------------+--------------------+--------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+--------------------+------------+-------------+--------------------+
# |      ID|Case Number|               Date|              Block|IUCR|        Primary Type|         Description|Location Description|Arrest|Domestic|Beat|District|Ward|Community Area|FBI Code|X Coordinate|Y Coordinate|Year|          Updated On|    Latitude|    Longitude|            Location|
# +--------+-----------+-------------------+-------------------+----+--------------------+--------------------+--------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+--------------------+------------+-------------+--------------------+
# |13997897|   JJ450669|2025-10-13 00:00:00| 090XX S BURLEY AVE|1710|OFFENSE INVOLVING...|ENDANGERING LIFE ...|           APARTMENT| false|   false| 424|       4|  10|            46|      20|     1199242|     1845609|2025|10/20/2025 03:43:...|41.731158264|-87.545686555|(41.731158264, -8...|
# |14001487|   JJ456213|2025-10-13 00:00:00|135XX S BRANDON AVE|0910| MOTOR VEHICLE THEFT|          AUTOMOBILE|           RESIDENCE| false|   false| 433|       4|  10|            55|      07|        NULL|        NULL|2025|10/20/2025 03:43:...|        NULL|         NULL|                NULL|
# |13996431|   JJ450180|2025-10-13 00:00:00| 018XX N LINDER AVE|0710|               THEFT|THEFT FROM MOTOR ...|              STREET| false|   false|2532|      25|  37|            25|      06|     1139442|     1911645|2025|10/20/2025 03:43:...|41.913664297| -87.76315256|(41.913664297, -8...|
# |13996029|   JJ449576|2025-10-13 00:00:00|    057XX W OHIO ST|0460|             BATTERY|              SIMPLE|              STREET| false|   false|1512|      15|  29|            25|     08B|     1137927|     1903397|2025|10/20/2025 03:43:...|41.891058284|-87.768917826|(41.891058284, -8...|
# |13996983|   JJ450693|2025-10-13 00:00:00|  081XX S ELLIS AVE|0810|               THEFT|           OVER $500|           APARTMENT| false|   false| 631|       6|   8|            44|      06|     1184307|     1851311|2025|10/20/2025 03:43:...|41.747167184|-87.600220148|(41.747167184, -8...|
# +--------+-----------+-------------------+-------------------+----+--------------------+--------------------+--------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+--------------------+------------+-------------+--------------------+
# only showing top 5 rows

# %%
# Afficher les colonnes
df.columns
# Out:
# ['ID',
#  'Case Number',
#  'Date',
#  'Block',
#  'IUCR',
#  'Primary Type',
#  'Description',
#  'Location Description',
#  'Arrest',
#  'Domestic',
#  'Beat',
#  'District',
#  'Ward',
#  'Community Area',
#  'FBI Code',
#  'X Coordinate',
#  'Y Coordinate',
#  'Year',
#  'Updated On',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
# Selectionner la colonne Descriptions et afficher les 5 premières lignes
df.select(col("Description")).show(5)
# Out:
# +--------------------+
# |         Description|
# +--------------------+
# |ENDANGERING LIFE ...|
# |          AUTOMOBILE|
# |THEFT FROM MOTOR ...|
# |              SIMPLE|
# |           OVER $500|
# +--------------------+
# only showing top 5 rows

# %%
# Selectionner la colonne Date, Description, Arrest et afficher leurs 5 première ligne
df.select("Date", "Description", "Arrest").show(5)
# Out:
# +-------------------+--------------------+------+
# |               Date|         Description|Arrest|
# +-------------------+--------------------+------+
# |2025-10-13 00:00:00|ENDANGERING LIFE ...| false|
# |2025-10-13 00:00:00|          AUTOMOBILE| false|
# |2025-10-13 00:00:00|THEFT FROM MOTOR ...| false|
# |2025-10-13 00:00:00|              SIMPLE| false|
# |2025-10-13 00:00:00|           OVER $500| false|
# +-------------------+--------------------+------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import to_timestamp, lit
from pyspark.sql.functions import to_timestamp, col

# %%
# Créer une nouvelle colonne contenant que 1

df.withColumn(
   "One",
   lit(1)
).show(5)
# Out:
# +--------+-----------+--------------------+-------------------+----+--------------------+--------------------+--------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+--------------------+------------+-------------+--------------------+---+
# |      ID|Case Number|                Date|              Block|IUCR|        Primary Type|         Description|Location Description|Arrest|Domestic|Beat|District|Ward|Community Area|FBI Code|X Coordinate|Y Coordinate|Year|          Updated On|    Latitude|    Longitude|            Location|One|
# +--------+-----------+--------------------+-------------------+----+--------------------+--------------------+--------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+--------------------+------------+-------------+--------------------+---+
# |13997897|   JJ450669|10/13/2025 12:00:...| 090XX S BURLEY AVE|1710|OFFENSE INVOLVING...|ENDANGERING LIFE ...|           APARTMENT| false|   false| 424|       4|  10|            46|      20|     1199242|     1845609|2025|10/20/2025 03:43:...|41.731158264|-87.545686555|(41.731158264, -8...|  1|
# |14001487|   JJ456213|10/13/2025 12:00:...|135XX S BRANDON AVE|0910| MOTOR VEHICLE THEFT|          AUTOMOBILE|           RESIDENCE| false|   false| 433|       4|  10|            55|      07|        NULL|        NULL|2025|10/20/2025 03:43:...|        NULL|         NULL|                NULL|  1|
# |13996431|   JJ450180|10/13/2025 12:00:...| 018XX N LINDER AVE|0710|               THEFT|THEFT FROM MOTOR ...|              STREET| false|   false|2532|      25|  37|            25|      06|     1139442|     1911645|2025|10/20/2025 03:43:...|41.913664297| -87.76315256|(41.913664297, -8...|  1|
------+--------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+--------------------+------------+-------------+--------------------+
# only showing top 5 rows

# %%
df.select("Date").show(5)
# Out:
# +--------------------+
# |                Date|
# +--------------------+
# |10/13/2025 12:00:...|
# |10/13/2025 12:00:...|
# |10/13/2025 12:00:...|
# |10/13/2025 12:00:...|
# |10/13/2025 12:00:...|
# +--------------------+
# only showing top 5 rows

# %%
# Compter le nombre des crimes signalés le 25-12-2023
one_day.count()
# Out:
# 25

# %%
# Compter le nombre de ligne distinct dans mon DataFrame
df.distinct().count()
# Out:
# 8425337

# %%
# Grouper les résultats par Type de crime et afficher les 20 premières lignes
df.groupBy("Primary Type").count().show()
# Out:
# +--------------------+-------+
# |        Primary Type|  count|
# +--------------------+-------+
# |OFFENSE INVOLVING...|  60472|
# |CRIMINAL SEXUAL A...|  11504|
# |            STALKING|   6159|
# |PUBLIC PEACE VIOL...|  54794|
# |           OBSCENITY|    957|
# |               ARSON|  14412|
# |            GAMBLING|  14664|
# |   CRIMINAL TRESPASS| 226684|
# |             ASSAULT| 564538|
# |LIQUOR LAW VIOLATION|  15392|
# | MOTOR VEHICLE THEFT| 430832|
# |               THEFT|1788460|
# |             BATTERY|1535214|
# |             ROBBERY| 314599|
# |            HOMICIDE|  13982|
# |    PUBLIC INDECENCY|    215|
# |   HUMAN TRAFFICKING|    138|
# |        INTIMIDATION|   5095|
# |        PROSTITUTION|  70417|
# |  DECEPTIVE PRACTICE| 388032|
# +--------------------+-------+
# only showing top 20 rows

# %%
# Le nombre de ligne distinct pour la colonne Arrest
df.select("Arrest").distinct().show()
# Out:
# +------+
# |Arrest|
# +------+
# |  true|
# | false|
# +------+

# %%
# Calcul du pourcentage du crime signalé de 2001 jusqu'a aujourd'hui
(df.filter(col("Arrest") == "true").count() / df.select("Arrest").count())*100
# Out:
# 25.22668232736566

# %%
# Les principaux lieux où les crimes sont signalés
n_location = df.groupBy("Location Description").count()
n_location.show()
# Out:
# +--------------------+------+
# |Location Description| count|
# +--------------------+------+
# |   RAILROAD PROPERTY|    18|
# |SCHOOL - PRIVATE ...|  1565|
# |VEHICLE - COMMERCIAL|  1327|
# |AIRPORT TERMINAL ...|  2693|
# |RESIDENCE - YARD ...| 15706|
# |CHA PARKING LOT /...|  2470|
# |            SIDEWALK|762682|
# |AIRPORT TERMINAL ...|   155|
# |OTHER RAILROAD PR...|   771|
# |            CAR WASH|  3615|
# |            HOSPITAL|    19|
# |    FEDERAL BUILDING|  1091|
# |         CTA STATION|  7906|
# |                FARM|    12|
# |               HOUSE|   712|
# |            CEMETARY|   438|
# |          VACANT LOT|   145|
# |TAVERN / LIQUOR S...|  2883|
# |PARKING LOT / GAR...| 46131|
# |            DRIVEWAY|    29|
# +--------------------+------+
# only showing top 20 rows

# %%
# Les trois principaux lieux où les crimes sont signalés
n_location.orderBy("count", ascending=False).show(3)
# Out:
# +--------------------+-------+
# |Location Description|  count|
# +--------------------+-------+
# |              STREET|2201552|
# |           RESIDENCE|1383493|
# |           APARTMENT|1001317|
# +--------------------+-------+
# only showing top 3 rows

# %%
# L'activité  criminelle la plus signalé
df.groupBy("Primary Type").count().orderBy("count", ascending=False).show()
# Out:
# +--------------------+-------+
# |        Primary Type|  count|
# +--------------------+-------+
# |               THEFT|1788460|
# |             BATTERY|1535214|
# |     CRIMINAL DAMAGE| 958132|
# |           NARCOTICS| 763802|
# |             ASSAULT| 564538|
# |       OTHER OFFENSE| 525339|
# |            BURGLARY| 445496|
# | MOTOR VEHICLE THEFT| 430832|
# |  DECEPTIVE PRACTICE| 388032|
# |             ROBBERY| 314599|
# |   CRIMINAL TRESPASS| 226684|
# |   WEAPONS VIOLATION| 124954|
# |        PROSTITUTION|  70417|
# |OFFENSE INVOLVING...|  60472|
# |PUBLIC PEACE VIOL...|  54794|
# |         SEX OFFENSE|  34200|
# | CRIM SEXUAL ASSAULT|  27283|
# |INTERFERENCE WITH...|  20219|
# |LIQUOR LAW VIOLATION|  15392|
# |            GAMBLING|  14664|
# +--------------------+-------+
# only showing top 20 rows

# %%
# L'activité  criminelle la moins signalé
df.groupBy("Primary Type").count().orderBy("count", ascending=True).show()
# Out:
# +--------------------+-----+
# |        Primary Type|count|
# +--------------------+-----+
# |   DOMESTIC VIOLENCE|    1|
# |           RITUALISM|   24|
# |        NON-CRIMINAL|   26|
# |   HUMAN TRAFFICKING|  138|
# |OTHER NARCOTIC VI...|  163|
# |    PUBLIC INDECENCY|  215|
# |           OBSCENITY|  957|
# |CONCEALED CARRY L...| 1646|
# |        INTIMIDATION| 5095|
# |            STALKING| 6159|
# |          KIDNAPPING| 7492|
# |CRIMINAL SEXUAL A...|11504|
# |            HOMICIDE|13982|
# |               ARSON|14412|
# |            GAMBLING|14664|
# |LIQUOR LAW VIOLATION|15392|
# |INTERFERENCE WITH...|20219|
# | CRIM SEXUAL ASSAULT|27283|
# |         SEX OFFENSE|34200|
# |PUBLIC PEACE VIOL...|54794|
# +--------------------+-----+
# only showing top 20 rows

# %%
df.select("Primary Type").show(30, truncate=False)
# Out:
# +-----------------------+
# |Primary Type           |
# +-----------------------+
# |ASSAULT                |
# |OTHER OFFENSE          |
# |THEFT                  |
# |CRIMINAL SEXUAL ASSAULT|
# |THEFT                  |
# |THEFT                  |
# |BATTERY                |
# |BATTERY                |
# |THEFT                  |
# |CRIMINAL DAMAGE        |
# |CRIMINAL DAMAGE        |
# |DECEPTIVE PRACTICE     |
# |THEFT                  |
# |BURGLARY               |
# |MOTOR VEHICLE THEFT    |
# |CRIMINAL SEXUAL ASSAULT|
# |CRIMINAL DAMAGE        |
# |BATTERY                |
# |ARSON                  |
# |BATTERY                |
# |THEFT                  |
# |ROBBERY                |
# |MOTOR VEHICLE THEFT    |
# |MOTOR VEHICLE THEFT    |
# |WEAPONS VIOLATION      |
# |CRIMINAL DAMAGE        |
# |CRIMINAL DAMAGE        |
# |ARSON                  |
# |ASSAULT                |
# |ASSAULT                |
# +-----------------------+
# only showing top 30 rows

# %%
# Le nombre de types de crime distinct
n_crime_type = df.select("Primary Type").distinct().count()
n_crime_type
# Out:
# 34

# %%
# Les activités non criminéls
df.select("Primary Type").distinct().show(n_crime_type, truncate=False)
# Out:
# +---------------------------------+
# |Primary Type                     |
# +---------------------------------+
# |OFFENSE INVOLVING CHILDREN       |
# |CRIMINAL SEXUAL ASSAULT          |
# |STALKING                         |
# |PUBLIC PEACE VIOLATION           |
# |OBSCENITY                        |
# |ARSON                            |
# |GAMBLING                         |
# |CRIMINAL TRESPASS                |
# |ASSAULT                          |
# |LIQUOR LAW VIOLATION             |
# |MOTOR VEHICLE THEFT              |
# |THEFT                            |
# |BATTERY                          |
# |ROBBERY                          |
# |HOMICIDE                         |
# |PUBLIC INDECENCY                 |
# |HUMAN TRAFFICKING                |
# |INTIMIDATION                     |
# |PROSTITUTION                     |
# |DECEPTIVE PRACTICE               |
# |CONCEALED CARRY LICENSE VIOLATION|
# |SEX OFFENSE                      |
# |CRIMINAL DAMAGE                  |
# |NARCOTICS                        |
# |NON-CRIMINAL                     |
# |OTHER OFFENSE                    |
# |KIDNAPPING                       |
# |BURGLARY                         |
# |WEAPONS VIOLATION                |
# |OTHER NARCOTIC VIOLATION         |
# |INTERFERENCE WITH PUBLIC OFFICER |
# |RITUALISM                        |
# |CRIM SEXUAL ASSAULT              |
# |DOMESTIC VIOLENCE                |
# +---------------------------------+

# %%
# Créer une DataFrame pour les activités non criminelles
nc = df.filter(
    (col("Primary Type") == "NON - CRIMINAL") | (col("Primary Type") == "NON-CRIMINAL") | (col("Primary Type") == "NON-CRIMINAL (SUBJECT SPECIFIED)"))
nc.show(5)
# Out:
# +--------+-----------+--------------------+--------------------+----+------------+--------------------+--------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+--------------------+------------+-------------+--------------------+
# |      ID|Case Number|                Date|               Block|IUCR|Primary Type|         Description|Location Description|Arrest|Domestic|Beat|District|Ward|Community Area|FBI Code|X Coordinate|Y Coordinate|Year|          Updated On|    Latitude|    Longitude|            Location|
# +--------+-----------+--------------------+--------------------+----+------------+--------------------+--------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+--------------------+------------+-------------+--------------------+
# |13833483|   JJ252198|05/12/2025 06:12:...|   040XX W GRAND AVE|1481|NON-CRIMINAL|CONCEALED CARRY L...|              STREET|  true|   false|2534|      25|  36|            23|      15|     1149224|     1909100|2025|05/20/2025 04:02:...|41.906496495|-87.727281102|(41.906496495, -8...|
# |13732526|   JJ129511|01/28/2025 12:25:...|    004XX S STATE ST|1481|NON-CRIMINAL|CONCEALED CARRY L...|              STREET|  true|   false| 113|       1|   4|            32|      15|     1176440|     1898296|2025|05/17/2025 03:40:...|41.876278587|   -87.627633|(41.876278587, -8...|
# |13710892|   JJ103416|01/04/2025 02:35:...| 011XX W SHERIDAN RD|1481|NON-CRIMINAL|CONCEALED CARRY L...|              STREET|  true|   false|2433|      24|  48|            77|      15|     1167249|     1942651|2025|05/17/2025 03:40:...|41.998193288|-87.660100094|(41.998193288, -8...|
# |13609390|   JH442628|09/24/2024 12:00:...|119XX S MICHIGAN AVE|1481|NON-CRIMINAL|CONCEALED CARRY L...|           RESIDENCE| false|   false| 532|       5|   9|            53|      15|     1178983|     1825922|2024|05/17/2025 03:40:...|41.677619207|-87.620498773|(41.677619207, -8...|
# |13575596|   JH402211|08/26/2024 01:39:...|    008XX N WELLS ST|1481|NON-CRIMINAL|CONCEALED CARRY L...|              STREET|  true|   false|1832|      18|   2|             8|      15|     1174588|     1905760|2024|05/17/2025 03:40:...| 41.89680182|-87.634209574|(41.89680182, -87...|
# +--------+-----------+--------------------+--------------------+----+------------+--------------------+--------------------+------+--------+----+--------+----+--------------+--------+------------+------------+----+--------------------+------------+-------------+--------------------+
# only showing top 5 rows

# %%
# Compter le nombre de ligne
nc.count()
# Out:
# 26

# %%
# L'activité non criminelle la plus signalé
nc.groupBy("Description").count().orderBy("count", ascending=False).show()
# Out:
# +--------------------+-----+
# |         Description|count|
# +--------------------+-----+
# |CONCEALED CARRY L...|   26|
# +--------------------+-----+
