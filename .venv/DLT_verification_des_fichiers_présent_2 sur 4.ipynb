-- %%
%python
# Verifier les fichiers présent dans mon dossier raw_data_files
dbutils.fs.ls("dbfs:/raw_data_files")
-- Out:
-- [FileInfo(path='dbfs:/raw_data_files/taxi_zone_lookup.csv', name='taxi_zone_lookup.csv', size=12331, modificationTime=1762933038000),
--  FileInfo(path='dbfs:/raw_data_files/yellow_tripdata_2025-01.parquet', name='yellow_tripdata_2025-01.parquet', size=59158238, modificationTime=1762934523000),
--  FileInfo(path='dbfs:/raw_data_files/yellow_tripdata_2025-02.parquet', name='yellow_tripdata_2025-02.parquet', size=60343086, modificationTime=1762934830000),
--  FileInfo(path='dbfs:/raw_data_files/yellow_tripdata_2025-03.parquet', name='yellow_tripdata_2025-03.parquet', size=69964745, modificationTime=1762935137000),
--  FileInfo(path='dbfs:/raw_data_files/yellow_tripdata_2025-04.parquet', name='yellow_tripdata_2025-04.parquet', size=67352824, modificationTime=1762935443000),
--  FileInfo(path='dbfs:/raw_data_files/yellow_tripdata_2025-05.parquet', name='yellow_tripdata_2025-05.parquet', size=77837865, modificationTime=1762935751000),
-- ...
