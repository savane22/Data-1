-- %%
SELECT
   *
FROM  read_files('dbfs:/raw_data_files/taxi_zone_lookup.csv', format => 'csv', header => true, inferSchema => true) LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT
  *, 
  substring_index(_metadata.file_path, '/', -1) AS file_name
FROM parquet.`dbfs:/raw_data_files/*.parquet` LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
%python
# Liste tous les fichiers dans le dossier DBFS
files = dbutils.fs.ls("dbfs:/raw_data_files/")

# Filtrer uniquement les fichiers Parquet
parquet_files = [f.path for f in files if f.path.endswith(".parquet")]

print("Fichiers Parquet trouvés :")
for f in parquet_files:
    print(f)
-- Out:
-- Fichiers Parquet trouvés :
-- dbfs:/raw_data_files/yellow_tripdata_2025-01.parquet
-- dbfs:/raw_data_files/yellow_tripdata_2025-02.parquet
-- dbfs:/raw_data_files/yellow_tripdata_2025-03.parquet
-- dbfs:/raw_data_files/yellow_tripdata_2025-04.parquet
-- dbfs:/raw_data_files/yellow_tripdata_2025-05.parquet
-- dbfs:/raw_data_files/yellow_tripdata_2025-06.parquet
-- dbfs:/raw_data_files/yellow_tripdata_2025-07.parquet
-- dbfs:/raw_data_files/yellow_tripdata_2025-08.parquet
-- dbfs:/raw_data_files/yellow_tripdata_2025-09.parquet

-- %%
SELECT COUNT(*) FROM parquet.`dbfs:/raw_data_files/*.parquet`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>35807453</td></tr></tbody></table></div>

-- %%
SELECT * FROM tripsdata.raw_trips LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT COUNT(*) FROM tripsdata.raw_trips;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>35807453</td></tr></tbody></table></div>

-- %%
SELECT DISTINCT file_name FROM tripsdata.raw_trips ORDER BY file_name;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>file_name</th></tr></thead><tbody><tr><td>yellow_tripdata_2025-01.parquet</td></tr><tr><td>yellow_tripdata_2025-02.parquet</td></tr><tr><td>yellow_tripdata_2025-03.parquet</td></tr><tr><td>yellow_tripdata_2025-04.parquet</td></tr><tr><td>yellow_tripdata_2025-05.parquet</td></tr><tr><td>yellow_tripdata_2025-06.parquet</td></tr><tr><td>yellow_tripdata_2025-07.parquet</td></tr><tr><td>yellow_tripdata_2025-08.parquet</td></tr><tr><td>yellow_tripdata_2025-09.parquet</td></tr></tbody></table></div>

-- %%
SELECT * FROM tripsdata.processed_trips LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT COUNT(*) FROM tripsdata.processed_trips;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>22169078</td></tr></tbody></table></div>

-- %%
SELECT * FROM tripsdata.aggregated_data LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT COUNT(*) FROM tripsdata.aggregated_data;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>100151</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) FROM FROM parquet.`dbfs:/raw_data_files/yellow_tripdata_2025-02.parquet`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>FROM</th></tr></thead><tbody><tr><td>3577543</td></tr></tbody></table></div>

-- %%
SELECT 3475226 + 3577543;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>(3475226 + 3577543)</th></tr></thead><tbody><tr><td>7052769</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) FROM parquet.`dbfs:/raw_data_files/yellow_tripdata_2025-03.parquet`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>4145257</td></tr></tbody></table></div>

-- %%
SELECT 7052769 + 4145257;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>(7052769 + 4145257)</th></tr></thead><tbody><tr><td>11198026</td></tr></tbody></table></div>
